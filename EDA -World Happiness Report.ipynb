# %% [markdown]
# # importing packages

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('2019.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (156, 9)

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# ## Top 10 happy countries

# %%
# df_top10 = df.groupby('Country or region')['Score'].max().sort_values(ascending=False).head(10).reset_index()

# df_top10

# %%
df_top10 = df[['Country or region', 'Score']].head(3)

df_top10
# Out:
#   Country or region  Score
# 0           Finland  7.769
# 1           Denmark  7.600
# 2            Norway  7.554

# %% [markdown]
# ## Top 10 Sad Countries

# %%
# df_bottom10 = df.groupby('Country or region')['Score'].max().sort_values(ascending=False).tail(10).reset_index()

# df_bottom10

# %%
df_bottom10 = df[['Country or region', 'Score']].tail(3)

df_bottom10
# Out:
#             Country or region  Score
# 153               Afghanistan  3.203
# 154  Central African Republic  3.083
# 155               South Sudan  2.853

# %% [markdown]
# ## Top 3 Countries with highest "GDB PER CAPITA"

# %%
df_top3_GDB = df[['GDP per capita', 'Country or region']].sort_values(by='GDP per capita', ascending=False).head(3)

df_top3_GDB
# Out:
#     GDP per capita Country or region
# 28           1.684             Qatar
# 13           1.609        Luxembourg
# 33           1.572         Singapore

# %% [markdown]
# ## Bottom 3 Countries with lowest "GDB PER CAPITA"

# %%
df_bottom3_GDB = df[['GDP per capita', 'Country or region']].sort_values(by='GDP per capita', ascending=False).tail(3)

df_bottom3_GDB
# Out:
#      GDP per capita         Country or region
# 144           0.046                   Burundi
# 154           0.026  Central African Republic
# 111           0.000                   Somalia

# %% [markdown]
# ## Top 3 Countries with highest "Social Support"

# %%
top3_social_sup = df[['Country or region', 'Social support']].sort_values(by='Social support', ascending=False).head(3)

top3_social_sup
# Out:
#   Country or region  Social support
# 3           Iceland           1.624
# 0           Finland           1.587
# 2            Norway           1.582

# %% [markdown]
# ## Bottom 3 Countries with lowest "Social Support"

# %%
bottom3_social_sup = df[['Country or region', 'Social support']].sort_values(by='Social support', ascending=False).tail(3)

bottom3_social_sup
# Out:
#             Country or region  Social support
# 101                     Benin           0.437
# 148                     Syria           0.378
# 154  Central African Republic           0.000

# %% [markdown]
# ## Top 3 Countries with highest "Healthy life expectancy"

# %%
top3_Hl_expectancy = df[['Country or region', 'Healthy life expectancy']].sort_values(by='Healthy life expectancy', ascending=False).head(3)

top3_Hl_expectancy
# Out:
#    Country or region  Healthy life expectancy
# 33         Singapore                    1.141
# 75         Hong Kong                    1.122
# 57             Japan                    1.088

# %% [markdown]
# ## Bottom 3 Countries with lowest "Healthy life expectancy"

# %%
bottom3_Hl_expectancy = df[['Country or region', 'Healthy life expectancy']].sort_values(by='Healthy life expectancy', ascending=False).tail(3)

bottom3_Hl_expectancy
# Out:
#             Country or region  Healthy life expectancy
# 143                   Lesotho                    0.168
# 154  Central African Republic                    0.105
# 134                 Swaziland                    0.000

# %% [markdown]
# ## Top 3 Countries with highest "Freedom to make life choices"

# %%
top3_Freedom_life_choices = df[['Country or region', 'Freedom to make life choices']].sort_values(by='Freedom to make life choices', ascending=False).head(3)

top3_Freedom_life_choices
# Out:
#     Country or region  Freedom to make life choices
# 40         Uzbekistan                         0.631
# 108          Cambodia                         0.609
# 2              Norway                         0.603

# %% [markdown]
# ## Bottom 3 Countries with lowest "Freedom to make life choices"

# %%
bottom3_Freedom_life_choices = df[['Country or region', 'Freedom to make life choices']].sort_values(by='Freedom to make life choices', ascending=False).tail(3)

bottom3_Freedom_life_choices
# Out:
#     Country or region  Freedom to make life choices
# 148             Syria                         0.013
# 155       South Sudan                         0.010
# 153       Afghanistan                         0.000

# %% [markdown]
# ## Top 3 Countries with highest "Generosity"

# %%
top3_Generosity = df[['Country or region', 'Generosity']].sort_values(by='Generosity', ascending=False).head(3)

top3_Generosity
# Out:
#     Country or region  Generosity
# 130           Myanmar       0.566
# 91          Indonesia       0.498
# 146             Haiti       0.419

# %% [markdown]
# ## Bottom 3 Countries with lowest "Generosity"

# %%
bottom3_Generosity = df[['Country or region', 'Generosity']].sort_values(by='Generosity', ascending=False).tail(3)

bottom3_Generosity
# Out:
#     Country or region  Generosity
# 89         Azerbaijan       0.035
# 147          Botswana       0.025
# 81             Greece       0.000

# %% [markdown]
# ## Top 3 Countries with highest "Perceptions of corruption"

# %%
top3_Pcorruption = df[['Country or region', 'Perceptions of corruption']].sort_values(by='Perceptions of corruption', ascending=False).head(3)

top3_Pcorruption
# Out:
#     Country or region  Perceptions of corruption
# 33          Singapore                      0.453
# 151            Rwanda                      0.411
# 1             Denmark                      0.410

# %% [markdown]
# ## Bottom 3 Countries with lowest "Perceptions of corruption"

# %%
bottom3_Pcorruption = df[['Country or region', 'Perceptions of corruption']].sort_values(by='Perceptions of corruption', ascending=False).tail(3)

bottom3_Pcorruption
# Out:
#    Country or region  Perceptions of corruption
# 47           Romania                      0.005
# 96          Bulgaria                      0.004
# 70           Moldova                      0.000

# %%
# displaying strong positive correlation that can play a major role to make anycountry happy
corr = df.corr()
strong_corr = corr[corr > 0.70]
strong_corr
# Out:
#                               Overall rank     Score  GDP per capita  \
# Overall rank                           1.0       NaN             NaN
# Score                                  NaN  1.000000        0.793883
# GDP per capita                         NaN  0.793883        1.000000
# Social support                         NaN  0.777058        0.754906
# Healthy life expectancy                NaN  0.779883        0.835462
# Freedom to make life choices           NaN       NaN             NaN
# Generosity                             NaN       NaN             NaN
# Perceptions of corruption              NaN       NaN             NaN
#
#                               Social support  Healthy life expectancy  \
# Overall rank                             NaN                      NaN
# Score                               0.777058                 0.779883
# GDP per capita                      0.754906                 0.835462
# ...

# %%
plt.figure(figsize=(15,7))

sns.heatmap(strong_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # what we have find?

# %% [markdown]
# - The country with the maximum GDP per capita is Qatar, whilst the country with the least GDP per capita is Somalia.
# - The country with the most social support is Iceland, and the country with the least is the Central African Republic.
# - The country with the highest healthy life expectancy is Singapore, and that with the lowest life expectancy is Swaziland.
# - The country with the most freedom is Uzbekistan, and the country with the least freedom is Afghanistan.
# - The country with the highest generosity is Myanmar, and the country with the lowest is Greece.
# - Finally, the country with the most negative perceptions of corruption is Singapore, and that of the most positive perceptions is Moldova.
#
#
# ##### We have seen a strong correlation of score with GDP per capita,  Social Support, Healthy life expectancy play an important role to make the country happy.
